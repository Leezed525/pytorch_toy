# %%
import math
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# 输出所有常见的激活函数的图像
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return 2 * sigmoid(2 * x) - 1

def relu(x):
    return np.maximum(0, x)

def leaky_relu(x, alpha=0.01):
    return np.maximum(alpha * x, x)

def swish(x, beta=1):
    return x * sigmoid(beta * x)

def mish(x):
    return x * tanh(np.log(1 + np.exp(x)))

# %%
x = np.linspace(1, 100, 100)
plt.figure(figsize=(12, 8))
# plt.plot(x, sigmoid(x), label='Sigmoid', color='blue')
# plt.plot(x, 2 * sigmoid(2 * x) - 1, label='Sigmoid', color='blue')
# plt.plot(x, tanh(x), label='Tanh', color='red')
# plt.plot(x, relu(x), label='ReLU', color='green')
# plt.plot(x, leaky_relu(x,0.2), label='Leaky ReLU', color='purple')
# plt.plot(x, leaky_relu(x,0.2), label='PReLU', color='purple')
# plt.plot(x, swish(x), label='Swish', color='black')
# plt.plot(x, mish(x), label='Mish', color='yellow')
plt.plot(x, x, label='Sigmoid', color='red')
# plt.plot(x, x*x, label='Sigmoid', color='blue')
plt.plot(x, [math.log2(a) for a in x], label='Sigmoid', color='green')

plt.legend()
plt.grid()
plt.show()
