# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plot


# 根据数组绘制折线图并在每个点上显示数字
plot.figure(figsize=(10, 6))
arr = [24,69,100,99,79,78,67,36,26,19]
plot.plot(arr)
for i in range(len(arr)):
    plot.text(i, arr[i], arr[i], ha='center', va='bottom')
plot.show()
